# %%
#### supoor vector macines the rial 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm 
from mlxtend.plotting import plot_decision_regions

# %%
data = pd.read_excel("/content/datos de entrada.xlsx")
print(data)
# Out:
#           X1        X2  y
# 0   1.220546  1.472174  0
# 1   1.266461  1.489608  0
# 2   1.291014  1.506078  0
# 3   1.278425  1.527805  0
# 4   1.312450  1.531961  0
# ..       ...       ... ..
# 91  1.408968  2.154262  1
# 92  2.194999  2.168689  3
# 93  2.676259  2.145902  4
# 94  3.021499  2.140656  4
# 95  1.520664  1.586557  0
#
# [96 rows x 3 columns]

# %%
PD_PSP = data["X1"]
Rf_a = data["X2"]
print(PD_PSP)
# Out:
# 0     1.220546
# 1     1.266461
# 2     1.291014
# 3     1.278425
# 4     1.312450
#         ...
# 91    1.408968
# 92    2.194999
# 93    2.676259
# 94    3.021499
# 95    1.520664
# Name: X1, Length: 96, dtype: float64

# %%
c = data["y"]
plt.scatter(PD_PSP, Rf_a, c = c)
plt.title("Abaco de todos los datos")
plt.legend()
plt.grid()
plt.xlabel("PD/PSP")
plt.ylabel("Rf/a")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
X = np.column_stack((PD_PSP, Rf_a))
y = data["y"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = svm.SVC(kernel = "poly", degree = 3, C = 1)
clf.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='poly')

# %%
clf.score(X_test, y_test)
# Out:
# 0.95

# %%
print(y_test)
type(y_test)
y_test = np.array(y_test)
print(y_test)
# Out:
# [2 3 0 5 1 0 3 3 0 2 0 0 0 4 1 1 0 3 3 0]
# [2 3 0 5 1 0 3 3 0 2 0 0 0 4 1 1 0 3 3 0]

# %%
plot_decision_regions(X = X_test, y = y_test, clf = clf, legend =2)
plt.grid()
plt.title("Abaco con datos de testing")
plt.xlabel("PD/PSP")
plt.ylabel("Rf/a")
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# Text(0, 0.5, 'Rf/a')

# %%
####### ABACO CON DATOS DE ENTRENAMIENTO #####

# %%
clf.score(X_train, y_train)
# Out:
# 0.9342105263157895

# %%
y_train = np.array(y_train)

# %%
plot_decision_regions(X = X_train, y = y_train, clf = clf, legend =2)
plt.grid()
plt.title("Abaco con datos de entrenamiento")
plt.xlabel("PD/PSP")
plt.ylabel("Rf/a")
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# Text(0, 0.5, 'Rf/a')
